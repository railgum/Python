# %%
from sympy import *
import math
from sympy.plotting import plot


x=symbols('x')
p1 = plot(x*x-5*x, show = false)
p2 = plot((x**3), show=false)
p1.append(p2[0])
p1.show()

# %%
x = symbols('x')
p1 = plot(x*x, show=False)
p2 = plot(32*(-x)**0.5, show=False)
p3 = plot(-32*x**0.5, show=False)
p4 = plot(-32*(-x)**0.5, show=False)
p5 = plot(32*x**0.5, show=False)
p6 = plot(-(x*x), show=False)
p1.append(p2[0])
p1.append(p3[0])
p1.append(p4[0])
p1.append(p5[0])
p1.append(p6[0])
p1.show()
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
from sympy import *
from sympy.plotting import plot

x = symbols('x')
expr = -12*x**4*sin(cos(x))-18*x**3+5*x**2+10*x-30
#expr1 = -12*x**4*sin(cos(x))
#expr2 = 18*x**3
#expr3 = 5*x**2
#expr4 = 10*x-30
#plot(expr1-expr2+expr3+expr4)
#plot(expr, (x,-10,10))
expr
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
nonlinsolve([expr],x)
# Out:
# {(ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes),)}

# %%
solveset(expr>0)
# Out:
# ConditionSet(x, -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30 > 0, Complexes)

# %%
solveset(expr<0)
# Out:
# ConditionSet(x, -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30 < 0, Complexes)

# %%
plot(expr,(x,-100,100))

# %%
heigth_expr = expr.diff(x)
nonlinsolve([heigth_expr],[x])
# Out:
# {(ConditionSet(x, Eq(12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10, 0), Complexes),)}
