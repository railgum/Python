# %%
print('Hello user!')
# Out:
# Hello user!

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.3-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 5.4 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      -------------------------------------- 965.4/965.4 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in x:\geek\developer\2_block\python\python\tutorial_env\lib\site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 8.3 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in x:\geek\developer\2_block\python\python\tutorial_env\lib\site-packages (from matplotlib) (23.0)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-win_amd64.whl (162 kB)
#      -------------------------------------- 163.0/163.0 kB 9.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 3.0 MB/s eta 0:00:00
# Collecting numpy>=1.19
#   Downloading numpy-1.24.1-cp310-cp310-win_amd64.whl (14.8 MB)
#      ---------------------------------------- 14.8/14.8 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in x:\geek\developer\2_block\python\python\tutorial_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.3 numpy-1.24.1 pillow-9.4.0 pyparsing-3.0.9

# %%
x=5
y=4
x+y
# Out:
# 9

# %%
from matplotlib import pyplot as plt
x = [1, 2, 8, 7, 4, 4, 9]
plt.plot(x)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from matplotlib import pyplot as plt
x = [x for x in range(-100,100)]
y = [t**3 for t in x]
plt.plot(x,y)
